# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
database_names = mongo.list_database_names()
database_names
# Out:
# ['admin',
#  'classDB',
#  'class_db',
#  'config',
#  'epa',
#  'fruits_db',
#  'gardenDB',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 1034540,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64ae0e7e89357a4723588519'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1034540',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
insert_result = establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
establishments.find_one({"BusinessName": "Penang Flavours"})
# Out:
# {'_id': ObjectId('64ae0e924be29cec6643b9c3'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
# establishments.find_one({"BusinessType": "Restaurant/Cafe/Canteen", "BusinessTypeID":""})

# Define the query and projection
query = {"BusinessType": "Restaurant/Cafe/Canteen"}
projection = {"BusinessTypeID", "Business Type" }

# Find the document matching the query and projection
result = establishments.find_one(query, projection)
result
# Out:
# {'_id': ObjectId('64ae0e7e89357a472358851a'), 'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(new_restaurant, {"$set": {"BusinessTypeID": 1}})

# %%
# Confirm that the new restaurant was updated
establishments.find_one({"BusinessName": "Penang Flavours"})
# Out:
# {'_id': ObjectId('64ae0e924be29cec6643b9c3'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({"LocalAuthorityName": "Dover"})

# %%
# Check if any remaining documents include Dover
establishments.count_documents({"LocalAuthorityName": "Dover"})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('64ae0e7e89357a4723588800'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.196408', 'latitude': '51.086058'},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set': {'geocode.longitude': {'$toDecimal': '$geocode.longitude'}, 
                                          'geocode.latitude': {'$toDecimal': '$geocode.latitude'}}}])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set': {'RatingValue': {'$toInt':'$RatingValue'}}}])

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('64ae0e7e89357a4723588800'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': 4,
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': Decimal128('1.196408'),
#   'latitude': Decimal128('51.086058')},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %%
# Check that the coordinates and rating value are now numbers
[doc for doc in establishments.find({}, ['RatingValue', 'geocode.longitude', 'geocode.latitude'])]
# Out:
# [{'_id': ObjectId('64ae0e7e89357a4723588800'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.196408'),
#    'latitude': Decimal128('51.086058')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588801'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.195625'),
#    'latitude': Decimal128('51.083812')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588803'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.194762'),
#    'latitude': Decimal128('51.085797')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588804'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588805'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588806'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588808'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588809'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358880a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358880b'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358880c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358880d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358880e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358880f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588810'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588811'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588812'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588813'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588814'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588815'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588816'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588817'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588818'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588819'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358881a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358881b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358881c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358881d'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358881e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358881f'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588820'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588821'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588822'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588823'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588824'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588825'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588826'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588827'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588828'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588829'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358882a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358882b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358882c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('64ae0e7e89357a472358882d'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.18794649942731'),
#    'latitude': Decimal128('51.0805695006979')}},
#  {'_id': ObjectId('64ae0e7e89357a472358882f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.187083'),
#    'latitude': Decimal128('51.080673')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588830'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.18516'),
#    'latitude': Decimal128('51.078449')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588831'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186825'),
#    'latitude': Decimal128('51.080446')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588832'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.202055'),
#    'latitude': Decimal128('51.095015')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588833'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18628335007084'),
#    'latitude': Decimal128('51.079985650005')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588834'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186485'),
#    'latitude': Decimal128('51.080284')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588837'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.194306'),
#    'latitude': Decimal128('51.087887')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588838'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186067'),
#    'latitude': Decimal128('51.080224')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588839'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186485'),
#    'latitude': Decimal128('51.080284')}},
#  {'_id': ObjectId('64ae0e7e89357a472358883a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.185368'),
#    'latitude': Decimal128('51.079613')}},
#  {'_id': ObjectId('64ae0e7e89357a472358883b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.185368'),
#    'latitude': Decimal128('51.079613')}},
#  {'_id': ObjectId('64ae0e7e89357a472358883c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188902'),
#    'latitude': Decimal128('51.083232')}},
#  {'_id': ObjectId('64ae0e7e89357a472358883d'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.183585'),
#    'latitude': Decimal128('51.077971')}},
#  {'_id': ObjectId('64ae0e7e89357a472358883f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.187056'),
#    'latitude': Decimal128('51.081735')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588840'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.184194'),
#    'latitude': Decimal128('51.07915')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588841'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186715'),
#    'latitude': Decimal128('51.081546')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588842'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186309'),
#    'latitude': Decimal128('51.080838')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588844'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.184194'),
#    'latitude': Decimal128('51.07915')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588846'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.184916'),
#    'latitude': Decimal128('51.0803')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588848'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1920251'),
#    'latitude': Decimal128('51.0877821')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588849'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18421399593353'),
#    'latitude': Decimal128('51.0804824829102')}},
#  {'_id': ObjectId('64ae0e7e89357a472358884a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18425798416138'),
#    'latitude': Decimal128('51.0804748535156')}},
#  {'_id': ObjectId('64ae0e7e89357a472358884b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.190896'),
#    'latitude': Decimal128('51.086262')}},
#  {'_id': ObjectId('64ae0e7e89357a472358884c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18421399593353'),
#    'latitude': Decimal128('51.0804824829102')}},
#  {'_id': ObjectId('64ae0e7e89357a472358884d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18601894378662'),
#    'latitude': Decimal128('51.0818061828613')}},
#  {'_id': ObjectId('64ae0e7e89357a472358884f'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.182962'),
#    'latitude': Decimal128('51.079301')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588850'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18431901931763'),
#    'latitude': Decimal128('51.0809478759766')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588851'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182962'),
#    'latitude': Decimal128('51.0793')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588852'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588853'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588854'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182875'),
#    'latitude': Decimal128('51.079905')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588855'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.183893'),
#    'latitude': Decimal128('51.080804')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588856'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.183894'),
#    'latitude': Decimal128('51.080805')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588857'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588858'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.080339')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588859'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.201433'),
#    'latitude': Decimal128('51.097794')}},
#  {'_id': ObjectId('64ae0e7e89357a472358885a'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.19522100055125'),
#    'latitude': Decimal128('51.0917365039471')}},
#  {'_id': ObjectId('64ae0e7e89357a472358885b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('64ae0e7e89357a472358885c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1835476'),
#    'latitude': Decimal128('51.0810258')}},
#  {'_id': ObjectId('64ae0e7e89357a472358885d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('64ae0e7e89357a472358885e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('64ae0e7e89357a472358885f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588860'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.080339')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588861'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588863'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.181832'),
#    'latitude': Decimal128('51.079889')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588864'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1813759803772'),
#    'latitude': Decimal128('51.079532623291')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588865'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1823865'),
#    'latitude': Decimal128('51.0802956')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588866'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.1822069'),
#    'latitude': Decimal128('51.0803409')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588867'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181365'),
#    'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588868'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181365'),
#    'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588869'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.181365'),
#    'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('64ae0e7e89357a472358886a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182125'),
#    'latitude': Decimal128('51.080412')}},
#  {'_id': ObjectId('64ae0e7e89357a472358886b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1817077'),
#    'latitude': Decimal128('51.0798931')}},
#  {'_id': ObjectId('64ae0e7e89357a472358886c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182125'),
#    'latitude': Decimal128('51.080412')}},
#  {'_id': ObjectId('64ae0e7e89357a472358886d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181482'),
#    'latitude': Decimal128('51.079799')}},
#  {'_id': ObjectId('64ae0e7e89357a472358886e'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.181483'),
#    'latitude': Decimal128('51.0798')}},
#  {'_id': ObjectId('64ae0e7e89357a472358886f'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.179446'),
#    'latitude': Decimal128('51.078209')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588870'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.190904'),
#    'latitude': Decimal128('51.089491')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588871'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18172800540924'),
#    'latitude': Decimal128('51.0806732177734')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588872'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1810166'),
#    'latitude': Decimal128('51.0797886')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588873'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1814856'),
#    'latitude': Decimal128('51.0802346')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588874'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1813097'),
#    'latitude': Decimal128('51.0800235')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588875'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588876'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588877'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.190904'),
#    'latitude': Decimal128('51.089491')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588878'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588879'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('64ae0e7e89357a472358887a'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('64ae0e7e89357a472358887b'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('64ae0e7e89357a472358887c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1817227'),
#    'latitude': Decimal128('51.0806941')}},
#  {'_id': ObjectId('64ae0e7e89357a472358887d'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.183327'),
#    'latitude': Decimal128('51.082322')}},
#  {'_id': ObjectId('64ae0e7e89357a472358887e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1802781'),
#    'latitude': Decimal128('51.0793698')}},
#  {'_id': ObjectId('64ae0e7e89357a472358887f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182609'),
#    'latitude': Decimal128('51.08164')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588880'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182609'),
#    'latitude': Decimal128('51.08164')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588881'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.185011'),
#    'latitude': Decimal128('51.083976')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588882'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588883'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588884'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588885'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588886'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.1826116'),
#    'latitude': Decimal128('51.0816612')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588887'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.185748'),
#    'latitude': Decimal128('51.08472')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588888'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.185748'),
#    'latitude': Decimal128('51.084721')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588889'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18279695510864'),
#    'latitude': Decimal128('51.0818634033203')}},
#  {'_id': ObjectId('64ae0e7e89357a472358888a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182753'),
#    'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('64ae0e7e89357a472358888b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18128204345703'),
#    'latitude': Decimal128('51.0804176330566')}},
#  {'_id': ObjectId('64ae0e7e89357a472358888c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181282'),
#    'latitude': Decimal128('51.080417')}},
#  {'_id': ObjectId('64ae0e7e89357a472358888d'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.181282'),
#    'latitude': Decimal128('51.080417')}},
#  {'_id': ObjectId('64ae0e7e89357a472358888e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182753'),
#    'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('64ae0e7e89357a472358888f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181023'),
#    'latitude': Decimal128('51.080181')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588890'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.182753'),
#    'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588891'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182356'),
#    'latitude': Decimal128('51.081494')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588892'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588893'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588894'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186977'),
#    'latitude': Decimal128('51.086189')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588895'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588896'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186241'),
#    'latitude': Decimal128('51.085454')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588897'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.179115'),
#    'latitude': Decimal128('51.078587')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588898'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186977'),
#    'latitude': Decimal128('51.086189')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588899'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17911505699158'),
#    'latitude': Decimal128('51.0785865783691')}},
#  {'_id': ObjectId('64ae0e7e89357a472358889a'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.1803396'),
#    'latitude': Decimal128('51.0798709')}},
#  {'_id': ObjectId('64ae0e7e89357a472358889b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1785097'),
#    'latitude': Decimal128('51.0780695')}},
#  {'_id': ObjectId('64ae0e7e89357a472358889c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1806797'),
#    'latitude': Decimal128('51.0802287')}},
#  {'_id': ObjectId('64ae0e7e89357a472358889d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('64ae0e7e89357a472358889e'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.1783613'),
#    'latitude': Decimal128('51.0781968')}},
#  {'_id': ObjectId('64ae0e7e89357a472358889f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1784815'),
#    'latitude': Decimal128('51.078117')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a0'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.1783613'),
#    'latitude': Decimal128('51.0781968')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a1'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.183784'),
#    'latitude': Decimal128('51.083569')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179729'),
#    'latitude': Decimal128('51.079632')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a3'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179729'),
#    'latitude': Decimal128('51.079632')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.183784'),
#    'latitude': Decimal128('51.083569')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a5'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18039'),
#    'latitude': Decimal128('51.080315')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18039'),
#    'latitude': Decimal128('51.080315')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1818685'),
#    'latitude': Decimal128('51.0818613')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888a9'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1818685'),
#    'latitude': Decimal128('51.0818613')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888aa'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178027'),
#    'latitude': Decimal128('51.078131')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ac'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179926'),
#    'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ad'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17884'),
#    'latitude': Decimal128('51.079161')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ae'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179926'),
#    'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888af'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179925'),
#    'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b0'),
#   'RatingValue': 1,
#   'geocode': {'longitude': Decimal128('1.1799178'),
#    'latitude': Decimal128('51.080217')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b1'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.181201'),
#    'latitude': Decimal128('51.081526')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178961'),
#    'latitude': Decimal128('51.079481')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b3'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178962'),
#    'latitude': Decimal128('51.079482')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178962'),
#    'latitude': Decimal128('51.079482')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b5'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.180846'),
#    'latitude': Decimal128('51.081337')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.180846'),
#    'latitude': Decimal128('51.081337')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177752'),
#    'latitude': Decimal128('51.0783483')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888b9'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1776046'),
#    'latitude': Decimal128('51.0783433')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ba'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.1817418'),
#    'latitude': Decimal128('51.0824157')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888bb'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188295'),
#    'latitude': Decimal128('51.088735')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888bc'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188295'),
#    'latitude': Decimal128('51.088735')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888bd'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888be'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888bf'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c0'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182136'),
#    'latitude': Decimal128('51.082867')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c3'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182136'),
#    'latitude': Decimal128('51.082867')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186371'),
#    'latitude': Decimal128('51.087132')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c5'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1796215'),
#    'latitude': Decimal128('51.0806446')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c6'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.1794011'),
#    'latitude': Decimal128('51.0804496')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179628'),
#    'latitude': Decimal128('51.080668')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179629'),
#    'latitude': Decimal128('51.080669')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888c9'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181896'),
#    'latitude': Decimal128('51.083108')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ca'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179629'),
#    'latitude': Decimal128('51.080669')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888cb'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.175486'),
#    'latitude': Decimal128('51.076896')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888cc'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176733'),
#    'latitude': Decimal128('51.078211')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888cd'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17673301696777'),
#    'latitude': Decimal128('51.0782127380371')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ce'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.1794486'),
#    'latitude': Decimal128('51.0808513')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888cf'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177506'),
#    'latitude': Decimal128('51.079081')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d0'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17957198619843'),
#    'latitude': Decimal128('51.0810699462891')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d1'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17799'),
#    'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177506'),
#    'latitude': Decimal128('51.079081')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d3'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17799'),
#    'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d4'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178969'),
#    'latitude': Decimal128('51.080624')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d5'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.17799'),
#    'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d7'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17575001716614'),
#    'latitude': Decimal128('51.0776252746582')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17799'),
#    'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888d9'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.174813'),
#    'latitude': Decimal128('51.076653')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888da'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888db'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888dc'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888dd'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888de'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.174605'),
#    'latitude': Decimal128('51.076956')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888df'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17352676391602'),
#    'latitude': Decimal128('51.0758056640625')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e0'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176296'),
#    'latitude': Decimal128('51.078718')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e1'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.174605'),
#    'latitude': Decimal128('51.076956')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1753663'),
#    'latitude': Decimal128('51.0776458')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e3'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176258'),
#    'latitude': Decimal128('51.07879')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e4'),
#   'RatingValue': 1,
#   'geocode': {'longitude': Decimal128('1.185418'),
#    'latitude': Decimal128('51.087185')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e5'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1762215'),
#    'latitude': Decimal128('51.0788531')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176296'),
#    'latitude': Decimal128('51.078718')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175897'),
#    'latitude': Decimal128('51.078513')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888e9'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ea'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175811'),
#    'latitude': Decimal128('51.078515')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888eb'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ec'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ed'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175811'),
#    'latitude': Decimal128('51.078515')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ee'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.189834'),
#    'latitude': Decimal128('51.09221')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ef'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.189833'),
#    'latitude': Decimal128('51.09221')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f0'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f1'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17591404914856'),
#    'latitude': Decimal128('51.0787391662598')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f2'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.184803'),
#    'latitude': Decimal128('51.087382')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f3'),
#   'RatingValue': 1,
#   'geocode': {'longitude': Decimal128('1.17584'),
#    'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17584'),
#    'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f5'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17584'),
#    'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17841398715973'),
#    'latitude': Decimal128('51.0812644958496')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17725700019713'),
#    'latitude': Decimal128('51.0806630002457')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17584'),
#    'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888f9'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.172728'),
#    'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888fa'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172728'),
#    'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888fb'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1748'),
#    'latitude': Decimal128('51.07856')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888fc'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888fd'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172728'),
#    'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888fe'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('64ae0e7e89357a47235888ff'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588900'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588901'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588902'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588903'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172055'),
#    'latitude': Decimal128('51.076413')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588904'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1842719'),
#    'latitude': Decimal128('51.0881644')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588905'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.174748'),
#    'latitude': Decimal128('51.079039')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588906'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.173056'),
#    'latitude': Decimal128('51.077492')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588907'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.17198'),
#    'latitude': Decimal128('51.076577')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588908'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175782'),
#    'latitude': Decimal128('51.080171')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588909'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175782'),
#    'latitude': Decimal128('51.080171')}},
#  {'_id': ObjectId('64ae0e7e89357a472358890a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172652'),
#    'latitude': Decimal128('51.077414')}},
#  {'_id': ObjectId('64ae0e7e89357a472358890b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.183925'),
#    'latitude': Decimal128('51.088333')}},
#  {'_id': ObjectId('64ae0e7e89357a472358890c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172652'),
#    'latitude': Decimal128('51.077414')}},
#  {'_id': ObjectId('64ae0e7e89357a472358890d'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.17198'),
#    'latitude': Decimal128('51.076577')}},
#  {'_id': ObjectId('64ae0e7e89357a472358890e'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.185859'),
#    'latitude': Decimal128('51.090286')}},
#  {'_id': ObjectId('64ae0e7e89357a472358890f'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.186289'),
#    'latitude': Decimal128('51.091129')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588910'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172314'),
#    'latitude': Decimal128('51.077702')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588911'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18468'),
#    'latitude': Decimal128('51.089337')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588912'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588913'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.16866'),
#    'latitude': Decimal128('51.074167')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588914'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588916'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588917'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1784191'),
#    'latitude': Decimal128('51.0833323')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588918'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588919'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('64ae0e7e89357a472358891a'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('64ae0e7e89357a472358891b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('64ae0e7e89357a472358891c'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('64ae0e7e89357a472358891d'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.177367'),
#    'latitude': Decimal128('51.082871')}},
#  {'_id': ObjectId('64ae0e7e89357a472358891e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.173416'),
#    'latitude': Decimal128('51.079192')}},
#  {'_id': ObjectId('64ae0e7e89357a472358891f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172054'),
#    'latitude': Decimal128('51.078068')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588920'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176219'),
#    'latitude': Decimal128('51.082381')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588921'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172452'),
#    'latitude': Decimal128('51.078885')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588922'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.174678'),
#    'latitude': Decimal128('51.081154')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588923'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.169515'),
#    'latitude': Decimal128('51.07623')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588924'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.169515'),
#    'latitude': Decimal128('51.07623')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588925'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.168516'),
#    'latitude': Decimal128('51.075403')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588926'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177755'),
#    'latitude': Decimal128('51.085001')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588927'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.171552'),
#    'latitude': Decimal128('51.078874')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588928'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177729'),
#    'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588929'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17363'),
#    'latitude': Decimal128('51.08129')}},
#  {'_id': ObjectId('64ae0e7e89357a472358892a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.173631'),
#    'latitude': Decimal128('51.081291')}},
#  {'_id': ObjectId('64ae0e7e89357a472358892b'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.177729'),
#    'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('64ae0e7e89357a472358892c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177729'),
#    'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('64ae0e7e89357a472358892d'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.179997'),
#    'latitude': Decimal128('51.088124')}},
#  {'_id': ObjectId('64ae0e7e89357a472358892e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.168984'),
#    'latitude': Decimal128('51.077243')}},
#  {'_id': ObjectId('64ae0e7e89357a472358892f'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.173631'),
#    'latitude': Decimal128('51.081291')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588930'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.181507'),
#    'latitude': Decimal128('51.088893')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588931'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179998'),
#    'latitude': Decimal128('51.088125')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588932'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17373'),
#    'latitude': Decimal128('51.0819')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588933'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178766'),
#    'latitude': Decimal128('51.087034')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588934'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178428'),
#    'latitude': Decimal128('51.086485')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588935'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178766'),
#    'latitude': Decimal128('51.087034')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588936'),
#   'RatingValue': 5,
# ...
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.137589'),
#    'latitude': Decimal128('51.084261')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c08'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.146772'),
#    'latitude': Decimal128('51.093315')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c09'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401727'),
#    'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c0b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401727'),
#    'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c0c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401727'),
#    'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c0d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.430937'),
#    'latitude': Decimal128('51.366877')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c0e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.430937'),
#    'latitude': Decimal128('51.366877')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c0f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.43093705177307'),
#    'latitude': Decimal128('51.3668785095215')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c10'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.142092'),
#    'latitude': Decimal128('51.089168')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c11'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.407923'),
#    'latitude': Decimal128('51.345305')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c13'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.166913'),
#    'latitude': Decimal128('51.113576')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c15'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.139687'),
#    'latitude': Decimal128('51.087407')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c16'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.135332'),
#    'latitude': Decimal128('51.083198')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c17'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.431917'),
#    'latitude': Decimal128('51.368648')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c18'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.39302098751068'),
#    'latitude': Decimal128('51.3317947387695')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c19'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.410663'),
#    'latitude': Decimal128('51.348733')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c1a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.410663'),
#    'latitude': Decimal128('51.348733')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c1b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.393021'),
#    'latitude': Decimal128('51.331795')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c1c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164273'),
#    'latitude': Decimal128('51.112388')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c1e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.42510104179382'),
#    'latitude': Decimal128('51.3635864257812')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c1f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.444029'),
#    'latitude': Decimal128('51.381812')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c20'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.142888'),
#    'latitude': Decimal128('51.091441')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c21'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.422112'),
#    'latitude': Decimal128('51.360875')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c22'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.433148'),
#    'latitude': Decimal128('51.371076')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c23'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.158123'),
#    'latitude': Decimal128('51.107275')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c24'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.14106'),
#    'latitude': Decimal128('51.091013')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c25'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.427302'),
#    'latitude': Decimal128('51.3663')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c26'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('0.959720015525818'),
#    'latitude': Decimal128('50.9134254455566')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c27'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.40673'),
#    'latitude': Decimal128('51.346842')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c28'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.137347'),
#    'latitude': Decimal128('51.087434')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c2a'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.1651994'),
#    'latitude': Decimal128('51.1150651')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c2b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1651994'),
#    'latitude': Decimal128('51.1150651')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c2c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.161841'),
#    'latitude': Decimal128('51.11213')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c2f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.393792'),
#    'latitude': Decimal128('51.335425')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c30'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.12104105949402'),
#    'latitude': Decimal128('51.0722274780273')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c32'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.160391'),
#    'latitude': Decimal128('51.110991')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c33'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.160391'),
#    'latitude': Decimal128('51.110991')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c34'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.415595'),
#    'latitude': Decimal128('51.35691')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c35'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.418731'),
#    'latitude': Decimal128('51.359859')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c36'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401173'),
#    'latitude': Decimal128('51.343189')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c37'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401173'),
#    'latitude': Decimal128('51.343189')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c38'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.121041'),
#    'latitude': Decimal128('51.072229')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c39'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('0.972863'),
#    'latitude': Decimal128('50.928769')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c3a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164221'),
#    'latitude': Decimal128('51.115816')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c3b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('0.972863'),
#    'latitude': Decimal128('50.928769')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c3c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164222'),
#    'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c3d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164222'),
#    'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c3e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.158654'),
#    'latitude': Decimal128('51.110454')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c3f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.121041'),
#    'latitude': Decimal128('51.072229')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c40'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.164222'),
#    'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c41'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.415953'),
#    'latitude': Decimal128('51.356504')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c42'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.140274'),
#    'latitude': Decimal128('51.092698')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c43'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.140274'),
#    'latitude': Decimal128('51.092698')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c44'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.138816'),
#    'latitude': Decimal128('51.090777')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c45'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.439276'),
#    'latitude': Decimal128('51.38035')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c46'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.413732'),
#    'latitude': Decimal128('51.356199')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c47'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.40902197360992'),
#    'latitude': Decimal128('51.3518028259277')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c48'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164371'),
#    'latitude': Decimal128('51.116532')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c4a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.16437101364136'),
#    'latitude': Decimal128('51.1165313720703')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c4b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.418525'),
#    'latitude': Decimal128('51.360944')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c4c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.4053856'),
#    'latitude': Decimal128('51.3485244')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c4d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1191845'),
#    'latitude': Decimal128('51.0726696')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c4e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.160059'),
#    'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c4f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.160059'),
#    'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c50'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.424766'),
#    'latitude': Decimal128('51.366986')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c51'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.160059'),
#    'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c52'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.3994987'),
#    'latitude': Decimal128('51.3429296')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c53'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.118816'),
#    'latitude': Decimal128('51.072477')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c54'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.170369'),
#    'latitude': Decimal128('51.122522')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c55'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.439561'),
#    'latitude': Decimal128('51.381088')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c57'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.134991'),
#    'latitude': Decimal128('51.088298')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c58'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.134991'),
#    'latitude': Decimal128('51.088298')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c59'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.4107282'),
#    'latitude': Decimal128('51.3539278')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c5a'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.410985'),
#    'latitude': Decimal128('51.354229')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c5d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.399246'),
#    'latitude': Decimal128('51.343344')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c5e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.427116'),
#    'latitude': Decimal128('51.369967')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c5f'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.43155097961426'),
#    'latitude': Decimal128('51.3743057250977')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c60'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.43155097961426'),
#    'latitude': Decimal128('51.3743057250977')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c61'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.427116'),
#    'latitude': Decimal128('51.369967')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c62'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.4271160364151'),
#    'latitude': Decimal128('51.3699684143066')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c63'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.134775'),
#    'latitude': Decimal128('51.088897')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c64'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.434777'),
#    'latitude': Decimal128('51.377667')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c65'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.431551'),
#    'latitude': Decimal128('51.374308')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c66'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.434777'),
#    'latitude': Decimal128('51.377667')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c67'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.412458'),
#    'latitude': Decimal128('51.356848')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c68'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.408037'),
#    'latitude': Decimal128('51.352702')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c69'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.42351'),
#    'latitude': Decimal128('51.367482')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c6a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.42351'),
#    'latitude': Decimal128('51.367482')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c6b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.398588'),
#    'latitude': Decimal128('51.343957')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c6c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.398588'),
#    'latitude': Decimal128('51.343957')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c6d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1688388'),
#    'latitude': Decimal128('51.1230953')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c6e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.420118'),
#    'latitude': Decimal128('51.364585')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c6f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.420118'),
#    'latitude': Decimal128('51.364585')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c70'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1688388'),
#    'latitude': Decimal128('51.1230953')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c71'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.426555'),
#    'latitude': Decimal128('51.370928')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c73'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.39900100231171'),
#    'latitude': Decimal128('51.3446922302246')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c74'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.426555'),
#    'latitude': Decimal128('51.370928')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c75'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.422304'),
#    'latitude': Decimal128('51.367121')}},
#  {'_id': ObjectId('64ae0e7e89357a4723588c76'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.400038'),
#    'latitude': Decimal128('51.345885')}},
#  ...]
